# %%
cd /gpfs/commons/instruments/pyseq/SND10310/20220801_4color/
# Out:
# /gpfs/commons/instruments/pyseq/SND10310/20220801_4color

# %%
cd images
# Out:
# /gpfs/commons/instruments/pyseq/SND10310/20220801_4color/images

# %%
ls
# Out:
# c558_A_ssd03315ba44triton1_r0_x10450_o7443.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o7678.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o7913.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o8148.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o8383.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o8618.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o8853.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o9088.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o9323.tiff
# c558_A_ssd03315ba44triton1_r0_x10450_o9558.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o7443.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o7678.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o7913.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o8148.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o8383.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o8618.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o8853.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o9088.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o9323.tiff
# c558_A_ssd03315ba44triton1_r0_x10765_o9558.tiff
# ...

# %%
import skimage
# Out:
# /nfs/sw/anaconda3/anaconda3-10.19/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
image = skimage.io.imread('/gpfs/commons/instruments/pyseq/SND10310/20220801_4color/images/c558_A_ssd03315ba44triton1_r0_x10450_o7913.tiff')

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
cd /gpfs/commons/groups/nygcfaculty/PySeq/20210323_4i4color/pipeline
# Out:
# /gpfs/commons/groups/nygcfaculty/PySeq/20210323_4i4color/pipeline

# %%
ls
# Out:
# 20210323_4i4color/  logs/                  results/
# images/             machine_settings.yaml  seg_images/

# %%
cd results
# Out:
# /gpfs/commons/groups/nygcfaculty/PySeq/20210323_4i4color/pipeline/results

# %%
ls
# Out:
# 20210323_4i4color/

# %%
cd 20210323_4i4color/
# Out:
# /gpfs/commons/groups/nygcfaculty/PySeq/20210323_4i4color/pipeline/results/20210323_4i4color

# %%
ls
# Out:
# masks/  segmentation/

# %%
cd semgmentation
# Out:
# [Errno 2] No such file or directory: 'semgmentation'
# /gpfs/commons/groups/nygcfaculty/PySeq/20210323_4i4color/pipeline/results/20210323_4i4color

# %%
cd segmentation
# Out:
# /gpfs/commons/groups/nygcfaculty/PySeq/20210323_4i4color/pipeline/results/20210323_4i4color/segmentation

# %%
ls
# Out:
# m1a.tiff
